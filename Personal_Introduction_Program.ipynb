# %% [markdown]
# <a href="https://colab.research.google.com/github/Samirdanish55/The_Developer_Arena_Internship_Project/blob/main/Personal_Introduction_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name? ")
age = input("How old are you? ")
hobby = input("What is your favorite hobby? ")

print("\n🎉 Welcome " + name + "! 🎉")
print("You are", age, "years old and love", hobby + ".")
# Out:
# What is your name? Alex
# How old are you? 21
# What is your favorite hobby? coding
#
# 🎉 Welcome Alex! 🎉
# You are 21 years old and love coding.
