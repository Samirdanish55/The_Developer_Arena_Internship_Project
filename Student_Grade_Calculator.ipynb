# %% [markdown]
# <a href="https://colab.research.google.com/github/Samirdanish55/The_Developer_Arena_Internship_Project/blob/main/Student_Grade_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter student name: ")
marks = int(input("Enter marks (0-100): "))

print(f"\n📊 RESULT FOR {name.upper()}:")
print(f"Marks: {marks}/100")

if marks >= 90:
    grade = "A"
    message = "Excellent! Keep shining! 🌟"
elif marks >= 80:
    grade = "B"
    message = "Very Good! Keep it up! 👍"
elif marks >= 70:
    grade = "C"
    message = "Good effort! 😊"
elif marks >= 50:
    grade = "D"
    message = "Needs Improvement 🙂"
else:
    grade = "F"
    message = "Better luck next time 💪"
print(f"Grade: {grade}")
print(f"Message: {message}")
# Out:
# Enter student name: Priya
# Enter marks (0-100): 85
#
# 📊 RESULT FOR PRIYA :
# Marks: 85/100
# Grade: B
# Message: Very Good! Keep it up! 👍
